# %% [markdown]
# ### OpenAI 설정

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
    )

# %% [markdown]
# ### Batch 검색

# %%
batch_job = client.batches.retrieve("batch_id") # replace with your batch id
dict(batch_job)
# Out:
# {'id': 'batch_676aa2f4fc2081909d1995a11a67a048',
#  'completion_window': '24h',
#  'created_at': 1735041781,
#  'endpoint': '/v1/chat/completions',
#  'input_file_id': 'file-Pk9ui24823feWhd8bjykR8',
#  'object': 'batch',
#  'status': 'completed',
#  'cancelled_at': None,
#  'cancelling_at': None,
#  'completed_at': 1735050539,
#  'error_file_id': None,
#  'errors': None,
#  'expired_at': None,
#  'expires_at': 1735128181,
#  'failed_at': None,
#  'finalizing_at': 1735046710,
#  'in_progress_at': 1735041787,
#  'metadata': None,
#  'output_file_id': 'file-EcAcgAVTSjX8bWgmhSRGxg',
#  'request_counts': BatchRequestCounts(completed=30000, failed=0, total=30000)}

# %% [markdown]
# ### 결과 검색

# %%
result_file_id = batch_job.output_file_id
print(result_file_id)

if result_file_id is not None: # 배치 작업이 끝나면 result_file_id가 생성됨
    result = client.files.content(result_file_id).content
else:
    print("No result file id found")
# Out:
# file-EcAcgAVTSjX8bWgmhSRGxg

# %%
result_file_name = "../../api_output/batch_job_results_translate_en-ko.jsonl"

# 파일로 저장
with open(result_file_name, "wb") as file:
    file.write(result)

# %%
import json

results = []
with open(result_file_name, "r") as file:
    for line in file:
        json_object = json.loads(line)
        results.append(json_object)

# %% [markdown]
# ### 결과 읽기 및 저장

# %%
for res in results[:5]:
    task_id = res['custom_id']
    idx = int(task_id.split('-')[1])
    result = json.loads(res['response']['body']['choices'][0]['message']['content'])
    print(f"Task ID: {task_id}, Index: {idx}\nEn: {result['sentences_en']}\nKo: {result['sentences_ko']}")
# Out:
# Task ID: task-0, Index: 0
# En: ['Serious people.', 'Could I say something?', 'I have your daughter.', 'What are we supposed to do?', "They're not even sure that he knows how to talk.", 'How long until the scanners are back online?', 'Now, will you get the luggage off immediately and take it straight to our rooms?', '-What does that mean?', "Johnny, it's seven and a half.", "He'll get himself killed."]
# Ko: ['진지한 사람들입니다.', '제가 한 말씀 드려도 될까요?', '제가 당신의 딸을 데리고 있습니다.', '우리는 무엇을 해야 하나요?', '그들은 그가 말을 할 줄 아는지조차 확신하지 못하고 있습니다.', '스캐너가 다시 작동하기까지 얼마나 걸리나요?', '지금 짐을 즉시 내려서 우리 방으로 바로 가져다 주시겠어요?', '-그게 무슨 뜻이에요?', 'Johnny, 그건 7.5입니다.', '그는 스스로를 위험에 빠뜨릴 것입니다.']
# Task ID: task-1, Index: 1
# En: ['My lord the Prince Alexandre de Grasillac de Morvan Lebro!', 'On the Enterprise, our condition is rapidly worsening.', "This is the 'young little white girl with the big black guys' scene.", 'Like you did with us.', 'There was one man who could tilt the balance. - Greetings, Pashabhai.', 'Quickly! - Hurry!', 'And where does the boss man sit?', '- They told you about that, huh?', 'God, please save me', 'Glienicke Bridge.']
# Ko: ['나의 주님, 알렉상드르 드 그라질락 드 모르반 레브로 공자님!', '엔터프라이즈에서 우리의 상황이 빠르게 악화되고 있습니다.', "이것은 '큰 흑인 남자들과 함께 있는 젊은 백인 소녀' 장면입니다.", '당신이 우리에게 했던 것처럼.', '균형을 뒤흔들 수 있는 남자가 한 명 있었습니다. - 안녕하세요, 파샤바이.', '빨리! - 서두르세요!', '그리고 보스는 어디에 앉아 있나요?', '- 그에 대해 들었군요?', '신이시여, 저를 구해 주세요.', '글리니케 다리.']
# Task ID: task-2, Index: 2
# En: ['Sugar is an essential energy source of the brain and...', "Take some cheese, it's good.", 'I really want to lose my inhibitions. You know, be able to talk to strangers. Break the ice.', 'Well, okay, then.', 'I need to get out of here.', 'I want to do it... there.', 'It is all I can do to keep you alive!', "But I couldn't say no.", 'I got a hundred bucks if you can be here in five. Thanks.', "Sometimes it's hard to tell."]
# Ko: ['설탕은 뇌의 필수 에너지 공급원입니다...', '치즈 좀 드세요, 맛있어요.', '저는 제 억제를 잃고 싶어요. 아시죠, 낯선 사람과 대화할 수 있게. 분위기를 깨고 싶어요.', '음, 알겠어요.', '여기서 나가야 해요.', '거기서 하고 싶어요.', '당신을 살리는 게 제가 할 수 있는 전부입니다!', '하지만 거절할 수 없었어요.', '5분 안에 여기 올 수 있다면 100달러 줄게요. 고마워요.', '가끔은 알기 어려워요.']
# Task ID: task-3, Index: 3
# En: ["Well, then we shouldn't disappoint them.", 'a new name ... - No, Jane.', 'Called the super. Mr. Johnson?', 'Not such great taste in men, you know, not to speak ill of the dead.', "Can't we just enjoy the silence for a bit?", "- He's taking everyone with him.", 'They thought they were honoring me.', "Tell me why the widow's so interested in you.", "I'll see what I can find out on the street, ya know?", 'Behold, Brynna the Fair.']
# Ko: ['그렇다면 우리는 그들을 실망시키지 말아야 합니다.', '새로운 이름 ... - 아니, 제인.', '관리자에게 전화했어. 존슨 씨?', '고인에 대해 나쁜 말을 하지 않겠지만, 남자에 대한 취향이 그리 좋지 않았죠.', '잠시 조용함을 즐길 수는 없을까요?', '- 그는 모두를 데려가고 있어요.', '그들은 나를 존경한다고 생각했어요.', '왜 과부가 당신에게 그렇게 관심이 많은지 말해 주세요.', '길거리에서 어떤 정보를 알아볼게요.', '보세요, 아름다운 브리나입니다.']
# Task ID: task-4, Index: 4
# En: ['I hear the handsome young prince coming.', "But the obvious problem for me is, well, we can't eat trees.", "I held my promise and didn't take anyone else.", 'Jacob, I want you to get that sub to a minimum safe distance.', "Yes? Can't you tell me why you're so unhappy?", 'Without more ado, the first item is a sketch about architects, called The Architects Sketch...', "I dressed nicely in my free time and started wearing lifts so I'd be a bit taller.", 'However, you could argue in some sense that hops constitute one of your five a day.', "Because if it is, you'll die right here!", 'What makes you any different?']
# Ko: ['잘생긴 젊은 왕자가 오는 소리가 들려요.', '하지만 저에게는 분명한 문제가 있는데, 나무는 먹을 수 없어요.', '나는 약속을 지켰고 다른 사람을 데려가지 않았어요.', '제이콥, 그 잠수함을 최소 안전 거리로 이동해 주세요.', '네? 왜 그렇게 불행한지 말해줄 수 없나요?', "더 이상 지체하지 않고, 첫 번째 항목은 '건축가의 스케치'라는 건축가에 관한 스케치입니다...", '여유가 있을 때 예쁘게 옷을 입고, 조금 더 키가 커 보이려고 굽 높은 신발을 신기 시작했어요.', '하지만 어떤 면에서는 홉이 당신의 하루 다섯 가지 채소와 과일 중 하나라고 주장할 수도 있어요.', '그렇다면 당신은 여기서 죽게 될 거예요!', '당신은 무엇이 달라요?']

# %%
import csv

with open("../../datasets/csv/TED2020+OpenSubtitles300k.csv", "w") as f_out:
    writer = csv.writer(f_out)
    writer.writerow(["en", "ko"])
    
    seen_pairs = set()
    
    for res in results:
        try:
            task_id = res['custom_id']
            idx = int(task_id.split('-')[1])
            result = json.loads(res['response']['body']['choices'][0]['message']['content'])
            sentences_en = result['sentences_en']
            sentences_ko = result['sentences_ko']
            
            for en, ko in zip(sentences_en, sentences_ko):
                pair = (en, ko)
                if pair not in seen_pairs:
                    writer.writerow([en, ko])
                    seen_pairs.add(pair)
        except:
            print(res)
# Out:
# {'id': 'batch_req_676ab7ea605081908a6c6b066e0a8b34', 'custom_id': 'task-3339', 'response': {'status_code': 200, 'request_id': '29b835cec8a112dc8a78ba34c3199c25', 'body': {'id': 'chatcmpl-Ahy3CRFOY7cNPlpqtwff5bpHcFqSN', 'object': 'chat.completion', 'created': 1735042302, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "I love my job, being The Flash.",\n        "Maybe I could\'ve forgiven you and helped raise your kid.",\n        "- They all did.",\n        "That\'s a $350 window.",\n        "And yet, across the gulf of space, minds immeasurably superior to ours regarded this earth with envious eyes, and, slowly and surely, they drew their', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 247, 'completion_tokens': 83, 'total_tokens': 330, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ab89ce86481908263de9cea4252ee', 'custom_id': 'task-4708', 'response': {'status_code': 200, 'request_id': '034edd67e7bc4d9d6b2b3e27a4e01df6', 'body': {'id': 'chatcmpl-Ahy69rwVZS792nL07m2w7FbZwkOQX', 'object': 'chat.completion', 'created': 1735042485, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "But we\'ve had long talks about staying in the tradition of the Connecticut house.",\n        "He dies, just not today.",\n        "~ A redheaded woman ~",\n        "It\'s possible the man on the tape was working for some old flame of hers.",\n        "You can talk to Ben\'s co-workers, find out what a doctor was doing way out here.",\n        "I can\'t believe I did it.",\n        "- Then what happened?",\n        "So, 60 seconds.",\n        "♪ When we finally kiss goodnight ♪",\n        "And just so we\'re clear, I want to clear up that hateful rumor... that I was the one who turned that closet case Sandy Ryerson in... because he gave Hank Saunders the', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 264, 'completion_tokens': 154, 'total_tokens': 418, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ab8d4a54c81909d61d3a6b7009932', 'custom_id': 'task-5158', 'response': {'status_code': 200, 'request_id': 'e76f10872768371671fbdb35a040343b', 'body': {'id': 'chatcmpl-Ahy7CUIxgVPp6koL8sQlk5EIngFk4', 'object': 'chat.completion', 'created': 1735042550, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "You have a problem?",\n        "You are his wife?",\n', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 235, 'completion_tokens': 23, 'total_tokens': 258, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ab9396fb88190a440b636c4450263', 'custom_id': 'task-5937', 'response': {'status_code': 200, 'request_id': 'c14ddda2a0ed028dae2b29c1bdf226b8', 'body': {'id': 'chatcmpl-Ahy8qOsFoNMbrq79ciBdSzGHKTirD', 'object': 'chat.completion', 'created': 1735042652, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "I of course replied",\n        "Let\'s take a ride downtown, clear this mess up.",\n        "She was engaged to Tony, the first probation worker.",\n        "I gave 18 years of my life to stand in the same spot as you!",\n        "You\'d never guess how ticked off we all were the day this was taken, but that was the thing about us Van De K', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 265, 'completion_tokens': 89, 'total_tokens': 354, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676aba1ab92081909aa601676bcbf44b', 'custom_id': 'task-7627', 'response': {'status_code': 200, 'request_id': 'f103e5d88b466847748e6b75d2490d5a', 'body': {'id': 'chatcmpl-AhyCFu2DaLR1u5ePGzZITWBf6jFAX', 'object': 'chat.completion', 'created': 1735042863, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "I-I know we\'re only doing this to fix all the stuff that we broke when we sold our souls for those damn rings, ok, but I-I loved you before I knew', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 258, 'completion_tokens': 45, 'total_tokens': 303, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676aba6d90348190924895ac243b354b', 'custom_id': 'task-8259', 'response': {'status_code': 200, 'request_id': 'a34ef0adec5ca6e0ffb0449b512318ef', 'body': {'id': 'chatcmpl-AhyDbDwSfoUGpWA6GSncXwP77roLc', 'object': 'chat.completion', 'created': 1735042947, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "That\'s Wally over there, and this is Emmett here.",\n        "Any kind of signal on that thing?",\n        "I choke myself every day, you bastard!",\n        "W-What is he d...",\n        "- We don\'t exactly know.",\n        "What are you doing here?",\n        "- But you promised me...",\n        "- Oh. - I was thinking, \\"Nancy Wheeler, she\'s not just another suburban girl who thinks she\'s rebelling by doing exactly what every other suburban girl does... until that phase passes and they marry some', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 277, 'completion_tokens': 117, 'total_tokens': 394, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676aba6f94c48190b6eb735e5b4170b9', 'custom_id': 'task-8276', 'response': {'status_code': 200, 'request_id': 'a65fecf7f4de201151588ed514f4c37d', 'body': {'id': 'chatcmpl-AhyDbqfrTFPocE69XSSTJji8TOPeP', 'object': 'chat.completion', 'created': 1735042947, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "For the tow truck.",\n        "It was like it wasn\'t me who was doing it, but it was.",\n        "Isn\'t the doc with you? No, he\'s missing.",\n        "Can anyone guess what this building was used for a hundred years ago... before you went to school here, before I went to this school even?",\n        "Wait', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 270, 'completion_tokens': 80, 'total_tokens': 350, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abb529bdc8190afacdf15365619cc', 'custom_id': 'task-9952', 'response': {'status_code': 200, 'request_id': 'ad36b7412837533bdcaf543b266ee4d8', 'body': {'id': 'chatcmpl-AhyH9cflw4fKvy9lfsTM9H3dePjgU', 'object': 'chat.completion', 'created': 1735043167, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "As brooks flow into streams, streams into rivers... and rivers into the sea... so our adepts flow back to us and swell our ranks.",\n        "I', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 259, 'completion_tokens': 43, 'total_tokens': 302, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abb5bc30881908b7ddd021379d026', 'custom_id': 'task-10020', 'response': {'status_code': 200, 'request_id': 'ba5588f2360e47d0138b4d8ab507254d', 'body': {'id': 'chatcmpl-AhyHMf6vic6tMxf9snLCa8mlsKRoD', 'object': 'chat.completion', 'created': 1735043180, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "We\'re evacuating as we speak.",\n        "This is the life\'s fair, breathing dance in the air.",\n        "You\'re happy with my report?",\n        "They need me in New York tomorrow.",\n        "Spring break, sophomore year, I got high in my bedroom... and my parents walked in and smelled it... so I told them that you had gotten stoned and jumped out', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 238, 'completion_tokens': 86, 'total_tokens': 324, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abb5c9fb88190b32920f7701c67a2', 'custom_id': 'task-10027', 'response': {'status_code': 200, 'request_id': '9ad99cdd1c6396b2272c2c675c6c18f3', 'body': {'id': 'chatcmpl-AhyHJzC52dHJd47khWvOWdlRZ2vw2', 'object': 'chat.completion', 'created': 1735043177, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "At the Bajoran Shrine on the Promenade.",\n        "They\'ve heard all about you and right about now, they could use something to smile about.",\n        "And most of them are all self-conscious about the smell factor.",\n        "And that is because we continuously adjust the way in which we look at the bones.",\n        "We also have to push one on the drone control panel, and we have to push it within 30 seconds of each other.",\n        "- Yes. So you will well get on.",\n        "Someone kind of woke me up.",\n        "It really isn\'t Mother\'s day.",\n        "440 million years ago a great mass extinction would kill off nearly every species on the planet, leaving the vast oceans decimated and', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 276, 'completion_tokens': 158, 'total_tokens': 434, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abd3a05d88190b4f7d00ba6ba836f', 'custom_id': 'task-13619', 'response': {'status_code': 200, 'request_id': '00d5ba9461f2aa9d2c4dc1d0789b7724', 'body': {'id': 'chatcmpl-AhyPAcLrW699C5YxRLGSDAbGI61dr', 'object': 'chat.completion', 'created': 1735043664, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 228, 'completion_tokens': 6, 'total_tokens': 234, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_d02d531b47'}}, 'error': None}
# {'id': 'batch_req_676abda83a0c81909ec90fca1bac29f2', 'custom_id': 'task-14516', 'response': {'status_code': 200, 'request_id': '80327989e98fb369a2341a127d4bc155', 'body': {'id': 'chatcmpl-AhyRKgOWh6PEIf9yFKBTkmL47MKU1', 'object': 'chat.completion', 'created': 1735043798, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Domitius turned away at the gate.",\n        "What do you know about Senator Hoffmeir?",\n        "One good punch and he\'s bursting up looking for the exit.",\n        "And if the only lead we can find comes from a freighter captain of questionable character, then that\'s good enough for me.",\n        "- Last night, somebody hijacked a trailer.",\n        "Then again, maybe not.",\n        "I know it\'s hard to go out... Incredible! ...when it\'s so cold, to give old clothes to strangers.",\n        "- Good morning.",\n        "Will the department let you do that?",\n        "Well, apart from making sure he eats his greens and getting him into a good school, yes."\n    ],\n    "sentences_ko": [\n        "도미티우스는 문에서 돌아섰습니다.",\n        "호프마이어 상원 의원에 대해 무엇을 알고 있나요?",\n        "한 번의 강한 주먹이면 그가 출구를 찾으러 나올 거예요.",\n        "만약 우리가 찾을 수 있는 유일한 단서가 의심스러운 성격의 화물선 선장에게서 온 것이라면, 그걸로 충분합니다.",\n        "- 어젯밤, 누군가 트레일러를 납치했습니다.",\n        "다시 생각해보면, 아닐 수도 있겠죠.",\n        "밖에 나가기가 힘든 건 알지만... 믿을 수 없네요! ...이렇게 추운 날에', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 258, 'completion_tokens': 322, 'total_tokens': 580, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_d02d531b47'}}, 'error': None}
# {'id': 'batch_req_676abdb5a2208190a6a8111b7a468614', 'custom_id': 'task-14630', 'response': {'status_code': 200, 'request_id': 'da108e1a365bab325a4e3e88368c033b', 'body': {'id': 'chatcmpl-AhyR4hugNjAsIqL7YX94Fj2C5EG3d', 'object': 'chat.completion', 'created': 1735043782, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "When do we start?",\n        "Those Boy Scouts have grown a foot since last year.",\n        "Girls, let\'s just talk about this for a second.",\n        "I spent all night trying to call you.",\n        "But that\'s just, like, a two-inch drop.",\n        "Someone\'s trying to cover their tracks and dead-end the investigation.",\n        "Intent is to deconstruct historical figures revered by prole sector thereby legitimizing current government policies.",\n        "WE DON\'T NEED TO FORGET THE FACE WE ONCE HAD (HERE IN 2016)",\n        "Jim, I want this.",\n        "That redhead, of course, was Mitchell, introducing me to the plucky orphan Annie... whose never-say-die attitude pulled this country out of a little thing called..."\n', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 272, 'completion_tokens': 168, 'total_tokens': 440, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abde8df408190be69cf132f6134c4', 'custom_id': 'task-15056', 'response': {'status_code': 200, 'request_id': '7cd25c6791e5bf1b15d42e9b463246f7', 'body': {'id': 'chatcmpl-AhyS3hS8mpimNFBGMiGT05APlaFEK', 'object': 'chat.completion', 'created': 1735043843, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Today, the action takes place in a distant time and place, which gives the viewer a sense of detachment from what\'s happening, a sense of separation.",\n        "Now, I\'ve experienced this firsthand.",\n        "If someone came to my door and I was hearing Catholic theology and dogma for the very first time, and they said, \'We believe that God impregnated a very young girl without the use of intercourse, and the fact that she was a virgin is maniacally important to us', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 377, 'completion_tokens': 109, 'total_tokens': 486, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abdfef7e881909e213e6566a7b972', 'custom_id': 'task-15234', 'response': {'status_code': 200, 'request_id': 'b1c514cabbcc3f6d8425d48f8a0118bf', 'body': {'id': 'chatcmpl-AhySLrmhWN5e1MmCXGT0EgNGhQ3XG', 'object': 'chat.completion', 'created': 1735043861, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "The full text was only published in 1973, over 30 years after its completion.",\n        "He moves his neck with ease, has had his feeding peg removed, breathes with his own lungs, speaks slowly with his own quiet voice, and works every day to gain more movement in his paralyzed body.",\n        "The innocuous makes space for the horrific.",\n        "Whereas the phone gave us the one-to-one pattern, and television, radio, magazines, books, gave us the one-to-many pattern, the Internet gives us the', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 325, 'completion_tokens': 121, 'total_tokens': 446, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abe17a59c8190ba255c4e6b09f871', 'custom_id': 'task-15437', 'response': {'status_code': 200, 'request_id': '9e716121f4b0dbd5115eb840aeaebff4', 'body': {'id': 'chatcmpl-AhySs9baZgJeo0u54EqDh8lwIQ8p7', 'object': 'chat.completion', 'created': 1735043894, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "But for that, I also had to give of myself.",\n        "And so here\'s what I found.",\n        "Instead of having a tray with two peas, I was hoping that they would go into the kitchen cabinet or the mother\'s handbag and do their museum-quality design collection on a tray.",\n        "And I just want you to think for a minute about what this entails.",\n        "The bear is a helpless victim tied to a tree, and the president of the United States decided to show it some mercy.",\n        "That\'s how most of us communicate.",\n        "I\'ll talk about vision, briefly.",\n        "He said, \'Dear James Veitch, We shall be shipping Gold to you.\'",\n        "(Recording) ♪ Sometimes in our lives ♪ ♪ We all have pain, we all have sorrow ♪ ♪ But if we are wise ♪ ♪ We know that there\'s always tomorrow ♪ ♪', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 406, 'completion_tokens': 187, 'total_tokens': 593, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abe1e3eb48190b2c5b40cbe200e7b', 'custom_id': 'task-15490', 'response': {'status_code': 200, 'request_id': '4c78ea26139a1fb5ef6f1f17bbd5e56a', 'body': {'id': 'chatcmpl-AhySu1vBhuGtLxBanAFD6PxU6Hlmh', 'object': 'chat.completion', 'created': 1735043896, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Well, I told you there would be a silver lining, and there is.",\n        "(Applause) ♫ Oh, a li la li la la la ♫ ♫ La li la la li la la la la la la ♫ (Applause) ♫ La li la la la ♫ ♫ La li la la la la ♫ ♫ La li la la la la la la ♫ ♫ La la la li la la la la la ♫ ♫ You\'ve been so kind and generous ♫ ♫ I don\'t know how you keep on giving. ♫ ♫ And for your kindness,', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 591, 'completion_tokens': 139, 'total_tokens': 730, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abe4869e081908ab150ff6dcb0032', 'custom_id': 'task-15819', 'response': {'status_code': 200, 'request_id': '379f0a74fae7bd4ec861b3c7bdce5c0b', 'body': {'id': 'chatcmpl-AhyTgDqEUhNBjp8P8ePBJ1EqZA3tn', 'object': 'chat.completion', 'created': 1735043944, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "On the contrary, what they said is, \\"We\'re here as a group to pull together with you, so together, we can figure out and fix this problem.\\"",\n        "There\'s something small there that responds.",\n        "Now what these transplants, these fecal transplants, or the poo tea suggest to me, and many other people have come up with this same idea, is that the microbial community in and on us, it\'s an organ.",\n        "One is short-range wireless, where you can actually communicate with the device from nearby, either through Bluetooth or wi-fi, and the other is long-range, where you can communicate with the car through the cellular network, or through one of the radio stations.",\n        "But we want to see a world where every country can do its best to stop its own outbreaks.",\n        "During the presidential election alone, the Internet Agency\'s efforts reached 126 million people on Facebook in the United States, issued three million individual tweets and 43 hours\' worth of YouTube content.",\n        "So let me explain these things.",\n        "But I think there\'s actually something much more interesting and fundamental going on here. The next big thing for me, the next big idea, we can find by going way back in history to the origins of language.",\n        "\\"Come on buddy, I have the toe clippers right here.",\n        "And I would say, \\"But that\'s crazy.\\""\n    ],\n    "sentences_ko": [\n        "오히려 그들이 말한 것은, \\"우리는 여러분과 함께 힘을 모으기 위해 그룹으로 여기 왔으니, 함께 이 문제를 해결할 수 있습니다.\\"입니다.",\n        "거기에는 작게 반응하는 무언가가 있습니다.",\n        "이 이식들, 즉 대변 이식이나 똥 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운 차가운  ...
# {'id': 'batch_req_676abe4e5d9881909939c8277fc42562', 'custom_id': 'task-15864', 'response': {'status_code': 200, 'request_id': '26cfbe69af5b7ca6f0bd7eb7e4a8247c', 'body': {'id': 'chatcmpl-AhyUNxeYWyHjIC7wwgfsRnAdt4BQ8', 'object': 'chat.completion', 'created': 1735043987, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Now we know room air is gloriously free, it is abundant, and it\'s already 21 percent oxygen.",\n        "Place your foot just so, mind how you turn: too swift a swivel can bring you down.",\n        "If we think of the mind as the metaphor of the music player, we see this.",\n        "The input doesn\'t really have to be meaningful.",\n        "(Laughter) I checked.",\n        "A plant, quite simply, needs light, it needs CO2, but even more importantly, it needs nutrients, which it draws from the soil.",\n        "I can show somebody a piece of hypertext, a page which has got links, and we click on the link and bing -- there\'ll be another hypertext page.",\n        "When the blog is active it heals itself within seconds.",\n        "(Laughter) Also, I\'ve got to tell you, I\'ve got 99 problems, and palsy is just one.",\n        "It\'s now legal for medical purposes in almost half our 50 states, millions of people can purchase their marijuana, their medicine, in government-licensed dispensaries, and over half my fellow', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 360, 'completion_tokens': 239, 'total_tokens': 599, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abe67419c8190a7c4666de351c7e5', 'custom_id': 'task-16064', 'response': {'status_code': 200, 'request_id': 'a78d75ce30cdd56cd9147707b17a96a5', 'body': {'id': 'chatcmpl-AhyVXGmMuKv0o0OZt92zuc3WSGY4q', 'object': 'chat.completion', 'created': 1735044059, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "or you\'ve been putting government or scientific data online, I just wanted to take this opportunity to say: Thank you very much, and we have only just started!",\n        "So what we wanted to do was produce this effect, this lighting effect, which made us have to bioengineer the wood walls.",\n        "The diversity of life in our homes is more than a list of 100,000 new species.",\n        "In the summer, you go to the beach.",\n        "Your uncle left the following note in his will: \\"I have created a puzzle.\\"",\n        "Now, you may say, but surely, what we\'ve seen on television about Saudi Islam convinces us that it can\'t possibly be compatible with what we consider the core of democracy -- namely, free political choice, basic liberty and basic equality.",\n        "So the non-avian dinosaurs are the big clunky ones that went extinct.",\n        "So I went and designed frame by frame to try to make this robot as graceful and engaging as possible.",\n        "And News, which I just mentioned, was started by a researcher.",\n        "I think it all started growing up in a fairly religious, moral family, eldest son of a rabbi, going off to university where I smoked some marijuana and I', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 410, 'completion_tokens': 266, 'total_tokens': 676, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abe9b170881909e23979bf4b9b2d8', 'custom_id': 'task-16465', 'response': {'status_code': 200, 'request_id': '06c31c455abfd0c98055a3db7ff81aec', 'body': {'id': 'chatcmpl-AhyVRQWBR6j9KK8VZqQKY8HtIZc1W', 'object': 'chat.completion', 'created': 1735044053, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "I\'ll get that lady at the laundromat who always seems to know what being nice is.",\n        "They took serious risks to learn.",\n        "We love things like plot twists and red herrings and surprise endings.",\n        "And if you\'re living in fecal material and it\'s surrounding you, you\'re going to get sick.",\n        "I\'ll tell you something else I learned, that the reason some drugs are legal and others not has almost nothing to do with science or health or the relative risk of drugs, and almost everything to', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 304, 'completion_tokens': 115, 'total_tokens': 419, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abea498548190b8df293610a54cdd', 'custom_id': 'task-16545', 'response': {'status_code': 200, 'request_id': '3cc88adaba31ecc7c65f3cb8be43dd18', 'body': {'id': 'chatcmpl-AhyVS7pn2sK5XQqP8LvTTPQbsqPY3', 'object': 'chat.completion', 'created': 1735044054, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "One evening while I was at home, I get a call from the ER, or the emergency room, from a city which is some 200 kilometers away from where I live.",\n        "But it wasn\'t all fun.",\n        "When I feel powerful, I feel confident, not fearful; I expand my own range.",\n        "They have in-built bidet nozzles for a lovely, hands-free cleaning experience, and they have various other features like a heated seat and an automatic lid-raising', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 320, 'completion_tokens': 110, 'total_tokens': 430, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_d02d531b47'}}, 'error': None}
# {'id': 'batch_req_676abea648948190abbfccb11bface75', 'custom_id': 'task-16558', 'response': {'status_code': 200, 'request_id': '8056629b1101cc7d063146844e0f0291', 'body': {'id': 'chatcmpl-AhyVc9jwX7oFD0D0bfrK4ZywBPSec', 'object': 'chat.completion', 'created': 1735044064, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "So there is some evidence that love is associated with changes to our moods and our behaviors.",\n        "It\'s as if the world is flattening off, isn\'t it?",\n        "The answer was absolutely yes.",\n        "This takes a second, but it\'s a distinctive stage.",\n        "There might be a crash. Certainly not sustainable.",\n        "And three, if children lie at a very young age, there must be some character flaws with them, and they are going to become pathological liars for life.",\n        "But, there is a problem.",\n        "A few years ago, oddly enough, I needed the bathroom, and I found one, a public bathroom, and I went into the stall, and I prepared to do what I\'d done most of my life: use the toilet, flush', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 323, 'completion_tokens': 169, 'total_tokens': 492, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abeb0a1a88190b434c9b52eb97889', 'custom_id': 'task-16641', 'response': {'status_code': 200, 'request_id': 'c7ea11b31f775da66152dd55f013c696', 'body': {'id': 'chatcmpl-AhyVfj5HAjEvVz5FU9S32t2CU37J5', 'object': 'chat.completion', 'created': 1735044067, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Today I\'m here, actually, to pose you a question.",\n        "To spend a trillion dollars on something -- that is not a conservative viewpoint.",\n        "As you can see, there\'s not a lot of difference between the way a Bonobo walks and the way an early australopithecine would have walked.",\n        "(Laughter) Let\'s make sure you have it.",\n        "Some fairy tales have happy endings. Some don\'t.",\n        "Bill Gates is one of those smartest guys of ours that work on these problems and he also funds this work, so thank you.",\n        "Those are the questions I learned at Health Leads, not in medical school.",\n        "Soon after my training, I found myself working first in Zimbabwe and then in India, and I was confronted by an altogether new reality.",\n        "So for me, impostor syndrome is a feeling of being well, well out of your depth, yet already entrenched in the situation.",\n        "It was done by Dr. Vince Felitti at Kaiser and Dr. Bob Anda at the CDC, and together, they asked 17,500 adults about their history', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 355, 'completion_tokens': 235, 'total_tokens': 590, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abeb45d888190b9739c65e0f1404f', 'custom_id': 'task-16672', 'response': {'status_code': 200, 'request_id': '54d96fa51582d4cdb20740a8c2b3d9af', 'body': {'id': 'chatcmpl-AhyVnHdKwUee8FVNX6QHjL3zcInWc', 'object': 'chat.completion', 'created': 1735044075, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "All right, so what does this mean?",\n        "I like this person!",\n        "So it\'s just as well that I\'m a workaholic.",\n        "By day three, she was comatose and on life support for kidney failure, lung failure and coma.",\n        "What lies within us can never be truly colonized, contorted, or taken away.",\n        "And this is extremely profound.",\n        "You know, in the 18th century in the U.K., the greatest preacher, greatest religious preacher, was a man called John Wesley, who went up and down', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 275, 'completion_tokens': 128, 'total_tokens': 403, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abec5e368819088084553d109e25b', 'custom_id': 'task-16825', 'response': {'status_code': 200, 'request_id': '81f210535322016bbf9ea8db677c9104', 'body': {'id': 'chatcmpl-AhyXaGmrc2XKy9uS5tXsYXSNlj5M9', 'object': 'chat.completion', 'created': 1735044186, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "This was on a monkey hunt, hunting with curare-tipped darts.",\n        "In the middle, you can see that little structure squeezing out, that\'s the left ventricle, pushing blood out through the aortic valve.",\n        "I was doing graffiti -- writing my name everywhere, using the city as a canvas.",\n        "So our feeling is, if it\'s good enough for the rugby team, it\'s good enough for health and poverty.",\n        "You know, none of us really tend to do the math on our transportation costs, and they\'re not going down any time soon.",\n        "This is a video chat application.",\n        "That means language can shape how you\'re thinking about anything that can be named by a noun.",\n        "(Laughter) (Applause) Now, I think a little bit like the IKEA effect, by getting people to work harder, they actually got them to love what they\'re doing to a higher degree', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 331, 'completion_tokens': 198, 'total_tokens': 529, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abec8886c81909d3e75f34cf7be5f', 'custom_id': 'task-16845', 'response': {'status_code': 200, 'request_id': '8c792093286f8fbc14bfa9a7b46114e1', 'body': {'id': 'chatcmpl-AhyX2SjdoHl3plNDP3yh0ctJ7kWDQ', 'object': 'chat.completion', 'created': 1735044152, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "So, for example, they might say \'taken from us\' rather than \'killed.\'",\n        "Looking at fossils dating back several millions of years -- it all points to evidence that life for the human species as we know it began right here.",\n        "You\'ve been called a whistleblower, a traitor, a hero.",\n        "What about electricity, roads and running water?",\n        "And then when they answered, I would inflate that number of balloons and give them that number of balloons to hold.",\n        "The Supreme Court said the doctrine protecting land all the way to the sky has no place in the modern world, otherwise every transcontinental flight would subject the operator to countless tres', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 336, 'completion_tokens': 149, 'total_tokens': 485, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abeca929c81909e3c683d886d63ff', 'custom_id': 'task-16861', 'response': {'status_code': 200, 'request_id': '65889a9768f7a7e214ffd564b641afb2', 'body': {'id': 'chatcmpl-AhyVrt6OrPmzHWfPDzIPosHMi4fiP', 'object': 'chat.completion', 'created': 1735044079, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Now, that might be gambling, that might be pornography, that might be cocaine, that might be cannabis, but you will bond and connect with something because that\'s our nature', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 369, 'completion_tokens': 44, 'total_tokens': 413, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abecdf3bc81909c91ad55d5f208e4', 'custom_id': 'task-16891', 'response': {'status_code': 200, 'request_id': 'b5bc12148ee00c662ee39e5dbbf8b753', 'body': {'id': 'chatcmpl-AhyWhdbyNWwY7OjGBpMkSiN8eoXhM', 'object': 'chat.completion', 'created': 1735044131, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Chris Anderson: I have been long so fascinated and amazed by so many aspects of Netflix.",\n        "To hear their ideas and their solutions?",\n        "There\'s adaptive exercises readily available for students.",\n        "Everybody can experience music in a profound way, we just have to make different tools.",\n        "I did a project where I took pictures of the hands of protesters and put them up and down the boarded-up buildings and community shops.",\n        "As people speak, they drift into new habits, shed old ones, make mistakes, and get creative.",\n        "Today, we are beginning to understand how to interrupt the progression from early adversity to disease and early death, and 30 years from now, the', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 403, 'completion_tokens': 150, 'total_tokens': 553, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abecf64d08190be2b257e7b68d034', 'custom_id': 'task-16904', 'response': {'status_code': 200, 'request_id': 'ca12f9d5d1e26acd34a60595d9462511', 'body': {'id': 'chatcmpl-AhyW2MYRGUwVeE4T75E8GKg87uIhH', 'object': 'chat.completion', 'created': 1735044090, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "The name of the book is \\"Islam Without Extremes: A Muslim Case for Liberty.\\"",\n        "We have arrived somewhere. We are thinking big.",\n        "Steve Jurvetson: Mmm, yes.",\n        "And openly supremacist movements rising, in many of our countries there are torches in the streets.",\n        "I suspect that not everybody in the audience is a geneticist.",\n        "The laser pierces the cell, while the cell swallows the drug in a matter of microseconds.",\n        "The thing that unites bilaterally symmetric animals is that their bodies are designed around movement.",\n        "(Music) ♫ Slide into the shimmering surface ♫ ♫ between two worlds. ♫ ♫ Standing at the center of time ♫ ♫ as it uncurls. ♫ ♫ Cutting through the veil of illusion. ♫ ♫ Moving beyond past conclusions.', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 904, 'completion_tokens': 192, 'total_tokens': 1096, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_d02d531b47'}}, 'error': None}
# {'id': 'batch_req_676abed0d8808190a7cf02970325e5ab', 'custom_id': 'task-16916', 'response': {'status_code': 200, 'request_id': '447149116b1f573cbd6d80e07a159e1c', 'body': {'id': 'chatcmpl-AhyWJ5Wb0NXUwkotaP4kiaE0DMJq3', 'object': 'chat.completion', 'created': 1735044107, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "If you zoom in here, you can see North Korea, in outline here, which is like a black hole compared to its neighbors.",\n        "We didn’t have to tell to the Nigerian filmmakers.",\n        "(Laughter) She said, \\"You\'re like the worst vulnerability role model ever.\\"",\n        "But these satellites that we rely on day in and day out have a finite life.",\n        "We need to build these pillars within our families and our institutions to help people become their best selves.",\n        "And somewhere in the middle of South Dakota, I turn to my friend and I ask her a question that\'s been bothering me for 2,000 miles.",\n        "My parents and I trusted her because we knew who she was and what she stood for, and she had no need to hide from', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 335, 'completion_tokens': 171, 'total_tokens': 506, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676abed5c1c48190a82f7ddf304fb493', 'custom_id': 'task-16958', 'response': {'status_code': 200, 'request_id': 'd6f8471efb4637af2f9ced6622005c9d', 'body': {'id': 'chatcmpl-AhyW9vMchhzSbs9RKbVCGEsACSNzx', 'object': 'chat.completion', 'created': 1735044097, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Because of the speed and brevity of social media, we are forced to jump to conclusions and write sharp opinions in 140 characters about complex world', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 347, 'completion_tokens': 39, 'total_tokens': 386, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# ...
# {'id': 'batch_req_676ac4cd87d88190a20d9f07c6da7b45', 'custom_id': 'task-29249', 'response': {'status_code': 200, 'request_id': '701fb0bab4472139cc6e2578dc869ec5', 'body': {'id': 'chatcmpl-Ahyxh1dJJxJGoHKAUdoxkjPMrzhvM', 'object': 'chat.completion', 'created': 1735045805, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "It\'s the case of a four-year-old who had a progressively enlarging head, and as a result, had loss of developmental milestones, neurologic milestones, and the reason for this problem is here -- it\'s called hydrocephalus.",\n        "Their work will constantly change.",\n        "To coordinate all the functions bacteria have, they have to be able to organize, and they do that just like us humans -- by communicating.",\n        "The six people in the photo are Xia Gang workers.",\n        "What\'s interesting to me is, these are called \'alternative education.\'",\n        "It\'s worth mentioning though that I didn\'t hate my body or my genitalia.",\n        "They\'re reporting five things: drop of truancy to almost zero, attending parent-teacher meetings -- which nobody did and now almost everybody does -- drop in discipline problems, increase in student participation.",\n        "If you look it up in the dictionary, something virtual is something that seems to exist but is not real.",\n        "It said, \'We were not there, that was not us doing the shooting, this did not happen.\'",\n        "And finally, point number three: Whatever one wants to say about Lesterland, against the background of its history, its traditions, in our land, in USA-land, Lesterland is', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 377, 'completion_tokens': 269, 'total_tokens': 646, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac4d2db2c8190ae73255881d032a4', 'custom_id': 'task-29292', 'response': {'status_code': 200, 'request_id': '7def6879a37639e7e330d7d38db19845', 'body': {'id': 'chatcmpl-AhyxicdwVx3dvFZlSjWhQvSFOphqj', 'object': 'chat.completion', 'created': 1735045806, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "But in the 1980s and \'90s, the electromagnet turns back on.",\n        "And this just -- we can\'t accept that.",\n        "We\'ve now saved over five million dollars while housing 650 people.",\n        "♫ Together: The Jill and Julia, the Jill and Julia, the Jill and Julia Show. ♫ ♫ Sobule: Why are all our heroes so imperfect? ♫ ♫ Why do they always bring me down? ♫ ♫ Why are all our heroes so imperfect? ♫ ♫ Statue in the park has lost his crown. ♫', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 355, 'completion_tokens': 130, 'total_tokens': 485, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac4d569748190b5435b10d9dfccda', 'custom_id': 'task-29313', 'response': {'status_code': 200, 'request_id': 'ae3723a302b66e607465687e5a928bcc', 'body': {'id': 'chatcmpl-AhyxlOJK5xWyV7W5eB9RBbWvAv4sF', 'object': 'chat.completion', 'created': 1735045809, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "But the data says something different.",\n        "They are the invisible engineers that control the chemistry of the ocean and therefore, what creatures can live there, whether or not it\'s safe for us to swim there and all of the other characteristics we sense with our eyes, noses and taste buds.",\n        "Sometimes it\'s an accumulation of feelings.",\n        "Stories can break the dignity of a people, but stories can also repair that broken dignity.",\n        "Lawyers take cases on contingency with the hope of a big share of a big settlement by a sympathetic jury, because this patient really ended up badly.",\n        "And he explained to me that, when I shave, I have little black dots on the left side of my face where the hair is, but on the right side of my face I was badly burned so I have no hair, and this creates lack of symmetry.",\n        "You\'d think they\'re coming from India. It\'s the closest place', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 395, 'completion_tokens': 197, 'total_tokens': 592, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac4d61684819084609ff8f0b0d295', 'custom_id': 'task-29318', 'response': {'status_code': 200, 'request_id': 'a0baa66339cc0544fbb9e5a88b3c6488', 'body': {'id': 'chatcmpl-AhyxmF1EjJkaP1foYZYzV41x8a0VT', 'object': 'chat.completion', 'created': 1735045810, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Those include physical, emotional, or sexual abuse; physical or emotional neglect; parental mental illness, substance dependence, incarceration; parental separation or', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 330, 'completion_tokens': 37, 'total_tokens': 367, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac4e023588190b29ba03fa171b0d2', 'custom_id': 'task-29401', 'response': {'status_code': 200, 'request_id': '4c9ba83cb467cd9370de0f2312f1e18b', 'body': {'id': 'chatcmpl-AhyxyVsqoDt8XBaCziBWLtZjQc7CE', 'object': 'chat.completion', 'created': 1735045822, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Mike is a little boy in Florida. He\'s 11 years old, and the thing that he loves most in the world is a show called \'My Little Pony: Friendship is Magic,\' like millions of other children across America.",\n        "A child entering school today will be my age in 2050.",\n        "It was fraudulent.",\n        "Every 30 seconds, somewhere on this planet, a child dies of malaria, and Paul Levy this morning, he was talking about the metaphor of the 727 crashing into the United States.",\n        "(Applause) Flight control is Brazilian. (Laughter) So we went together with these guys and we basically put this exoskeleton together, 15 degrees of freedom, hydraulic machine that can be commanded by brain signals recorded by a non-invasive technology called electroencephalography that can basically allow the patient to imagine the movements and send his commands to the controls, the motors, and get it done.",\n        "I\'m not sure what they\'re smoking.",\n        "Life forms are divided into two camps: autotrophs, like plants, that generate their own energy, and heterotrophs, like animals, that consume other organisms for energy.",\n        "The two really bad ideas that are hovering in the modern world that inhibit our capacity to draw strength from art: The first idea is that art should', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 467, 'completion_tokens': 280, 'total_tokens': 747, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac4e8a8dc8190bf87d2b604203943', 'custom_id': 'task-29475', 'response': {'status_code': 200, 'request_id': '5bb8ec585bb43fbc8c7b3ecc534bd35d', 'body': {'id': 'chatcmpl-AhyyC39HUBNezYGP0lEjMPCbEpKzR', 'object': 'chat.completion', 'created': 1735045836, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "(Laughter) (Applause) I guess it goes without saying that we\'ve had a lot of fun doing this.",\n        "They\'re finding that the brain is like a patchwork mosaic -- a mixture.",\n        "Being the perpetual new face in class, I was frequently the target of bullies.",\n        "When it\'s difficult to make out the difference between the lung of a smoker and the lung of a nonsmoker, we have a real problem, because I can run an air purifier at home, but can I lock up my daughter at home?",\n        "Serena, a 32-year-old accountant, says that it\'s important to her for her doctor to share her values when it comes to reproductive choice and women\'s rights.",\n', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 379, 'completion_tokens': 156, 'total_tokens': 535, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac4f472b88190bb728338a496f4e8', 'custom_id': 'task-29577', 'response': {'status_code': 200, 'request_id': '706e4e5e6415bda6cb24458589546e04', 'body': {'id': 'chatcmpl-AhyyTBE4BliZ8jqZMQMpQ0UrRAQS3', 'object': 'chat.completion', 'created': 1735045853, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Some of you remember this, I\'m sure.",\n        "These are the kinds of inequities that kill people.",\n        "In these initiation camps, you are taught how to sexually please a man.",\n        "What this tells us, ethical issues aside, is that ...",\n        "Now, researchers need to make every effort to ensure that an intervention that has been shown to be beneficial during a clinical trial is accessible to the participants of the trial once the trial has been completed.",\n        "We probably wouldn\'t have looked at the data at all, and if we did look at the data, we\'d probably have said, \\"Fantastic! What a smart guy who is performing this low,\\" because he would', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 345, 'completion_tokens': 148, 'total_tokens': 493, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac5107a5c81908438edaaea8ca93f', 'custom_id': 'task-29799', 'response': {'status_code': 200, 'request_id': 'd454e32f2cb2b9f0a93fbe2dfbaf4566', 'body': {'id': 'chatcmpl-Ahyz6Mb1woCsypdXjJXBZKpfRlKvn', 'object': 'chat.completion', 'created': 1735045892, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "Trillions are born here, but only a few make it to adulthood.",\n        "We took a lot of meetings and we seriously considered it.",\n        "It\'s a pathological, democracy-destroying corruption, because in any system where the members are dependent upon the tiniest fraction of us for their election, that means the tiniest number of us, the tiniest', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 384, 'completion_tokens': 84, 'total_tokens': 468, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac51174108190a4694a35a3e0a4fb', 'custom_id': 'task-29807', 'response': {'status_code': 200, 'request_id': '0dbef94c94b410d980b25444051b06ee', 'body': {'id': 'chatcmpl-Ahyz7D4kkw8u8zzMDgVrdq02U0kZq', 'object': 'chat.completion', 'created': 1735045893, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "We have lots of cells that are not out for themselves anymore.",\n        "You can run these off -- they\'re really hungry, they really like down-blended weapons pits, so that\'s highly enriched uranium and weapons-grade', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 318, 'completion_tokens': 52, 'total_tokens': 370, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}
# {'id': 'batch_req_676ac5240ebc81909847388c35a97049', 'custom_id': 'task-29961', 'response': {'status_code': 200, 'request_id': '53313dc6f9490edb14f459f04861e96c', 'body': {'id': 'chatcmpl-AhyzXCz7wlvzJi9KYNf4tXQvUVSaC', 'object': 'chat.completion', 'created': 1735045919, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n    "sentences_en": [\n        "And I\'ve been on the receiving end of that, and it doesn\'t feel very good.",\n        "Well, as the Supreme Court said in Citizens United, we could say, of course the people have the ultimate influence over the elected officials.",\n        "We have a general election, but only', 'refusal': None}, 'logprobs': None, 'finish_reason': 'content_filter'}], 'usage': {'prompt_tokens': 322, 'completion_tokens': 67, 'total_tokens': 389, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'system_fingerprint': 'fp_0aa8d3e20b'}}, 'error': None}

# %% [markdown]
# ### Huggingface에 업로드

# %%
from datasets import load_dataset

datasets = load_dataset("csv", data_files="../../datasets/csv/TED2020+OpenSubtitles300k.csv", split="train")

datasets.push_to_hub(repo_id="Jooinjang/my_translate_300k_en-ko", private=True)
# Out:
# Creating parquet from Arrow format: 100%|██████████| 297/297 [00:00<00:00, 1082.03ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:04<00:00,  4.78s/it]
# CommitInfo(commit_url='https://huggingface.co/datasets/Jooinjang/my_translate_300k_en-ko/commit/48b24db010b945d3e2762f338fe0aed9ac6daabc', commit_message='Upload dataset', commit_description='', oid='48b24db010b945d3e2762f338fe0aed9ac6daabc', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Jooinjang/my_translate_300k_en-ko', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Jooinjang/my_translate_300k_en-ko'), pr_revision=None, pr_num=None)

# %%
datasets[100:110]
# Out:
# {'en': ['-For helping you move the bricks!',
#   'All the children available for adoption have some genetic advantage.',
#   "I'm trying to communicate.",
#   "It's at the hotel.",
#   'Non, merci, quand meme.',
#   "I'm kind of a vegetarian.",
#   'So you feel like telling me what happened to you that night now?',
#   "It's a blessed spot.",
#   'There is a new proconsul in the Romulan Senate.',
#   "I made Dimpy lie, goldy's stomach isn't aching I wanted to meet you.."],
#  'ko': ['- 벽돌 옮기는 걸 도와주기 위해서요!',
#   '입양 가능한 모든 아이들은 유전적으로 어떤 장점이 있어요.',
#   '저는 소통하려고 하고 있어요.',
#   '그것은 호텔에 있어요.',
#   '아니요, 감사합니다, 그럼에도 불구하고.',
#   '저는 채식주의자 같은 편이에요.',
#   '그래서 이제 그날 밤 당신에게 무슨 일이 있었는지 말해줄 기분인가요?',
#   '그곳은 축복받은 장소예요.',
#   '로물루스 상원에 새로운 총독이 생겼어요.',
#   '제가 딤피에게 거짓말하게 했어요, 골디의 배는 아프지 않아요, 당신을 만나고 싶었어요.']}

# %%
from datasets import load_dataset

ds = load_dataset("Jooinjang/my_translate_300k_en-ko", split="train")

ds.train_test_split(test_size=0.1)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['en', 'ko'],
#         num_rows: 266773
#     })
#     test: Dataset({
#         features: ['en', 'ko'],
#         num_rows: 29642
#     })
# })
